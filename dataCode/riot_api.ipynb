# %%
import requests
api_key = ""
#WARNING: SET YOUR API KEY HERE more info: https://developer.riotgames.com
#WARNING: DO NOT PUSH THIS KEY TO GITHUB OR ANYWHERE ELSE PUBLIC (by Samynhn)

# %%
# get summoner info
summoner_name = "God Thunder"
summoner_name_for_save_path = "Zeus"
region = "asia"
contry = "KR"
SUMMONER_V4 = "https://" + contry + ".api.riotgames.com/lol/summoner/v4/summoners/by-name/"
SUMMONER_V4_URL = SUMMONER_V4 + summoner_name + "?api_key=" + api_key
response = requests.get(SUMMONER_V4_URL)
summoner_data = response.json()
encryptedPUUID = summoner_data['puuid']
print(encryptedPUUID)
# it may like : bEN5d9HH5CGcQR4N9M-s5fEfufdFMSgNUyQLam8cmtxy8krWZQe22c5TVuQKe23yb6hg9xsT6gKmXw
# Out:
# 2WPMYAxqvcBIa0VTCZeeOD4-rNjZuPj2wmiSxfReP6698MOsbzuN_YK482OSaywApucVPNig0GKIgw

# %%
# get game detail
import json
def get_game_detail(game_name, region="asia", api_key=api_key):
    MATCH_V5_1 = "https://" +region+ ".api.riotgames.com/lol/match/v5/matches/"
    MATCH_V4_1_URL = MATCH_V5_1 + game_name + "?api_key=" + api_key
    response = requests.get(MATCH_V4_1_URL)
    data = response.json()
    return data
game_detail = get_game_detail("KR_6796022666")
json_response = json.dumps(game_detail) # aviod single quote in json
print(json_response) 
#it may like: {"metadata": {"dataVersion": "2", "matchId": "KR_6796022666", "participants": ["ZsTHjo...
# Out:
# {"metadata": {"dataVersion": "2", "matchId": "KR_6796022666", "participants": ["ZsTHjonxAsBQlaAd5FV3yCY0qEUZyGhrAIKs4mDJKb4BDaqG27P_6jlKVYssYxXdbZjywwi1jLyMrA", "18Ttib-yhRcIxwwgFqZpnAZvJoDnyjU40tme_u4m6eNhdTutS1V2h0_i1QS2UEY_c1LVnmxaiWpk0Q", "bEN5d9HH5CGcQR4N9M-s5fEfufdFMSgNUyQLam8cmtxy8krWZQe22c5TVuQKe23yb6hg9xsT6gKmXw", "1BebjTGXdc4N09AWL9EJFX5hyyVZu8T75tDxAuBKLeW7_jKGRVmWP5f42Lszhri1CjnoWdC73sT9jg", "tFBy-mqJEgC2NCo4OZEQhtqOn21Q5fi377J-4v_RS68VnffY98R9R8y2n_cJjwSvUmdxfzKdN13P_A", "rPGt3i0WgIZqx-9A9KDz2egqWxngL7lk4uTaP9d7J_r-lZvejWGwVzgiom43ZzDnqaUI8MexRPt0gA", "x58IPmmgdF2CkseIWK6HpX9fCdR6olmDZZEdRMoVJqWXym-bw26OTd4R9KROpa5hRoOhlqZxjPv-bQ", "12vWUD0mIVKdhsj6NdoFpkIls5bHDWuMl3qE6r7mFTnQdqsGm6bqLSGiaQqo_V0HJ_zJdsxwrKw1Cg", "7qVxqjNAhcWkh-qswUTFi9tJR5hBXSLGNYtn7tHdflygVVFLqnuxNVmnmOUTh_wuz8Ah8TMprBMRQw", "57Qe8PjGpga7nfiyqkzLLG-ltCq_dJLm7jUFeIZ4DBYJTwi2RhGK4PSoe8kUDaXZ3AydpCCidzA4Hw"]}, "info": {"gameCreation": 1699885652548, "gameDuration": 921, "gameEndTimestamp": 1699886633215, "gameId": 6796022666, "gameMode": "CLASSIC", "gameName": "teambuilder-match-6796022666", "gameStartTimestamp": 1699885711585, "gameType": "MATCHED_GAME", "gameVersion": "13.22.541.9804", "mapId": 11, "participants": [{"allInPings": 0, "assistMePings": 0, "assists": 1, "baitPings": 0, "baronKills": 0, "basicPings": 0, "bountyLevel": 3, "challenges": {"12AssistStreakCount": 0, "abilityUses": 117, "acesBefore15Minutes": 0, "alliedJungleMonsterKills": 0, "baronTakedowns": 0, "blastConeOppositeOpponentCount": 0, "bountyGold": 0, "buffsStolen": 0, "completeSupportQuestInTime": 0, "controlWardsPlaced": 0, "damagePerMinute": 611.3739969801964, "damageTakenOnTeamPercentage": 0.24371564555904865, "dancedWithRiftHerald": 0, "deathsByEnemyChamps": 2, "dodgeSkillShotsSmallWindow": 0, "doubleAces": 0, "dragonTakedowns": 0, "earlyLaningPhaseGoldExpAdvantage": 1, "effectiveHealAndShielding": 0, "elderDragonKillsWithOpposingSoul": 0, "elderDragonMultikills": 0, "enemyChampionImmobilizations": 15, "enemyJungleMonsterKills": 0, "epicMonsterKillsNearEnemyJungler": 0, "epicMonsterKillsWithin30SecondsOfSpawn": 0, "epicMonsterSteals": 0, "epicMonsterStolenWithoutSmite": 0, "firstTurretKilled": 0, "flawlessAces": 0, "fullTeamTakedown": 0, "gameLength": 921.8017896, "getTakedownsInAllLanesEarlyJungleAsLaner": 0, "goldPerMinute": 403.01742922543787, "hadOpenNexus": 0, "immobilizeAndKillWithAlly": 3, "initialBuffCount": 0, "initialCrabCount": 0, "jungleCsBefore10Minutes": 0, "junglerTakedownsNearDamagedEpicMonster": 0, "kTurretsDestroyedBeforePlatesFall": 0, "kda": 2.5, "killAfterHiddenWithAlly": 0, "killParticipation": 0.21739130434782608, "killedChampTookFullTeamDamageSurvived": 0, "killingSprees": 1, "killsNearEnemyTurret": 1, "killsOnOtherLanesEarlyJungleAsLaner": 0, "killsOnRecentlyHealedByAramPack": 0, "killsUnderOwnTurret": 0, "killsWithHelpFromEpicMonster": 0, "knockEnemyIntoTeamAndKill": 0, "landSkillShotsEarlyGame": 0, "laneMinionsFirst10Minutes": 64, "laningPhaseGoldExpAdvantage": 0, "legendaryCount": 0, "lostAnInhibitor": 0, "maxCsAdvantageOnLaneOpponent": 14, "maxKillDeficit": 0, "maxLevelLeadLaneOpponent": 1, "mejaisFullStackInTime": 0, "moreEnemyJungleThanOpponent": 0, "multiKillOneSpell": 0, "multiTurretRiftHeraldCount": 0, "multikills": 0, "multikillsAfterAggressiveFlash": 0, "outerTurretExecutesBefore10Minutes": 0, "outnumberedKills": 0, "outnumberedNexusKill": 0, "perfectDragonSoulsTaken": 0, "perfectGame": 0, "pickKillWithAlly": 3, "playedChampSelectPosition": 1, "poroExplosions": 0, "quickCleanse": 0, "quickFirstTurret": 0, "quickSoloKills": 0, "riftHeraldTakedowns": 0, "saveAllyFromDeath": 0, "scuttleCrabKills": 0, "skillshotsDodged": 7, "skillshotsHit": 0, "snowballsHit": 0, "soloBaronKills": 0, "soloKills": 2, "stealthWardsPlaced": 4, "survivedSingleDigitHpCount": 0, "survivedThreeImmobilizesInFight": 4, "takedownOnFirstTurret": 0, "takedowns": 5, "takedownsAfterGainingLevelAdvantage": 0, "takedownsBeforeJungleMinionSpawn": 0, "takedownsFirstXMinutes": ...

# %%
#output format: [summoner_name, summoner_team, summoner_position, summoner_champion, summoner_winFlag, opponent_name, opponent_team, opponent_position, opponent_champion, opponent_winFlag, gameMode, gameType]
def get_summoner_and_opponent_info(data, encryptedPUUID=encryptedPUUID):
    gameMode = data['info']['gameMode']
    # print(gameMode)
    gameType = data['info']['gameType']
    # print(gameType)
    gameVersion = data['info']['gameVersion']
    
    champion_names = [participant['championName'] for participant in data['info']['participants']]
    teamPositions = [participant['teamPosition'] for participant in data['info']['participants']]
    summonerNames = [participant['summonerName'] for participant in data['info']['participants']]
    winFlag = [participant['win'] for participant in data['info']['participants']]
    teams = ["red", "red", "red", "red", "red", "blue", "blue", "blue", "blue", "blue"]

    #get summoner's position, champion
    participants = data['metadata']['participants']
    summoner_index = participants.index(encryptedPUUID)
    summoner_name = summonerNames[summoner_index]
    summoner_team = teams[summoner_index]
    summoner_position = teamPositions[summoner_index]
    summoner_champion = champion_names[summoner_index]
    summoner_winFlag = winFlag[summoner_index]

    # get summoner's opponent position, champion
    def find_opponent_index(my_index, team_size=5):
        # 如果是红队，加上团队大小；如果是蓝队，减去团队大小
        opponent_index = (my_index + team_size) % (2 * team_size)
        return opponent_index
    opponent_index = find_opponent_index(summoner_index)
    opponent_name = summonerNames[opponent_index]
    opponent_team = teams[opponent_index]
    opponent_position = teamPositions[opponent_index]
    opponent_champion = champion_names[opponent_index]
    opponent_winFlag = winFlag[opponent_index]

    return [gameVersion, summoner_name, summoner_team, summoner_position, summoner_champion, summoner_winFlag, opponent_name, opponent_team, opponent_position, opponent_champion, opponent_winFlag, gameMode, gameType]

# %%
import csv
import os
def summoner_and_opponent_info_writer(output_path, summoner_and_opponent_info):
    fieldnames = ["gameVersion", "summoner_name", "summoner_team", "summoner_position", "summoner_champion", "summoner_winFlag", "opponent_name", "opponent_team", "opponent_position", "opponent_champion", "opponent_winFlag"]
    
    # 检查文件是否已存在，如果不存在则写入表头
    file_exists = os.path.isfile(output_path)

    with open(output_path, 'a', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        
        # 仅在文件不存在时写入表头
        if not file_exists:
            writer.writeheader()
        
        writer.writerow({
            "gameVersion": summoner_and_opponent_info[0],
            "summoner_name": summoner_and_opponent_info[1],
            "summoner_team": summoner_and_opponent_info[2],
            "summoner_position": summoner_and_opponent_info[3],
            "summoner_champion": summoner_and_opponent_info[4],
            "summoner_winFlag": summoner_and_opponent_info[5],
            "opponent_name": summoner_and_opponent_info[6],
            "opponent_team": summoner_and_opponent_info[7],
            "opponent_position": summoner_and_opponent_info[8],
            "opponent_champion": summoner_and_opponent_info[9],
            "opponent_winFlag": summoner_and_opponent_info[10]
        })

# %%
#save game_name_arr to json file
import json
def save_game_name_arr_to_json(output_path, game_name_arr):
    with open(output_path, 'w') as outfile:
        json.dump(game_name_arr, outfile)

# %%
# According to the Riot API documentation, the rate limit for a personal keys is by design very limited:
# The rate limit for a personal keys is by design very limited:
# 20 requests every 1 second
# 100 requests every 2 minutes

import time
def request_limit_checker(request_num):
    if request_num != 0:
        print("request_limit_checker #ACTIVE")
        if request_num % 16 == 0: # 80% of 20
            print("sleep 1s")
            time.sleep(1)
            print("wake up")
        if request_num % 80 == 0: # 80% of 100
            print("sleep 120s")
            time.sleep(120)
            print("wake up")

# %%
#get game detail
import time
MATCH_V5 = "https://" + region + ".api.riotgames.com/lol/match/v5/matches/by-puuid/"
request_num = 0
start = 0;
count = 100;
number_of_request = 10; #get 10000 games
game_name_arr = []
classic_game_history_csv_path = "../data/"+ summoner_name_for_save_path +"game_history/classic_game_history.csv"
classic_game_name_history_json_path = "../data/"+ summoner_name_for_save_path +"game_history/classic_game_name_history.json"

for per_request in range(number_of_request): 
    request_num += 1
    request_limit_checker(request_num)
    MATCH_V5_URL = MATCH_V5 + encryptedPUUID + "/ids?start=" + str(start) + "&count=" + str(count) + "&api_key=" + api_key
    response = requests.get(MATCH_V5_URL)
    game_names_per_request = response.json()
    print("#PROGRESSING: Iteration: " + str(start))
    if len(game_names_per_request) == 0:
        print("#FINISH: No more games")
        break
    else:
        for game_name in game_names_per_request:
            print("#PROGRESSING: Iteration: " + str(start) + "." + str(request_num))
            request_num+=1
            request_limit_checker(request_num)
            game_detail = get_game_detail(game_name) #json format to string(first data)
            #save game detail to json file
            json_response = json.dumps(game_detail)
            json_file_path = "../data/" + "log" + ".json"
            with open(json_file_path, 'w') as outfile:
                outfile.write(json_response)

            gameType = game_detail['info']['gameType']
            gameMode = game_detail['info']['gameMode']
            if gameType == "MATCHED_GAME" and gameMode == "CLASSIC":
                game_name_arr += [game_name]
                summoner_and_opponent_info = get_summoner_and_opponent_info(game_detail)
                summoner_and_opponent_info_writer(classic_game_history_csv_path, summoner_and_opponent_info)
                # print("SUCCESS: " + str(iteration))
            # else:
            #     print("FAIL: " + str(iteration) + " " + gameType + " " + gameMode)
    start +=count #next 100 games when count = 100

save_game_name_arr_to_json(classic_game_name_history_json_path, game_name_arr)
print("#FINISH: save_game_name_arr_to_json")
# Out:
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0
# #PROGRESSING: Iteration: 0.1
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.2
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.3
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.4
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.5
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.6
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.7
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.8
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.9
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.10
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.11
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.12
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.13
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.14
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.15
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 0.16
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.17
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.18
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.19
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.20
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.21
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.22
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.23
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.24
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.25
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.26
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.27
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.28
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.29
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.30
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.31
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 0.32
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.33
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.34
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.35
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.36
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.37
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.38
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.39
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.40
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.41
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.42
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.43
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.44
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.45
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.46
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.47
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 0.48
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.49
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.50
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.51
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.52
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.53
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.54
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.55
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.56
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.57
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.58
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.59
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.60
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.61
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.62
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.63
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 0.64
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.65
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.66
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.67
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.68
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.69
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.70
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.71
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.72
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.73
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.74
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.75
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.76
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.77
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.78
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.79
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# sleep 120s
# wake up
# #PROGRESSING: Iteration: 0.80
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.81
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.82
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.83
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.84
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.85
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.86
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.87
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.88
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.89
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.90
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.91
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.92
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.93
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.94
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.95
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 0.96
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.97
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.98
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.99
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 0.100
# request_limit_checker #ACTIVE
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100
# #PROGRESSING: Iteration: 100.102
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.103
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.104
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.105
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.106
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.107
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.108
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.109
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.110
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.111
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 100.112
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.113
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.114
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.115
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.116
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.117
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.118
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.119
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.120
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.121
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.122
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.123
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.124
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.125
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.126
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.127
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 100.128
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.129
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.130
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.131
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.132
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.133
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.134
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.135
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.136
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.137
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.138
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.139
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.140
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.141
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.142
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.143
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 100.144
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.145
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.146
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.147
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.148
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.149
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.150
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.151
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.152
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.153
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.154
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.155
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.156
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.157
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.158
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.159
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# sleep 120s
# wake up
# #PROGRESSING: Iteration: 100.160
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.161
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.162
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.163
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.164
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.165
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.166
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.167
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.168
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.169
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.170
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.171
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.172
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.173
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.174
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.175
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 100.176
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.177
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.178
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.179
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.180
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.181
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.182
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.183
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.184
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.185
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.186
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.187
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.188
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.189
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.190
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.191
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 100.192
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.193
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.194
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.195
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.196
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.197
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.198
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.199
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.200
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 100.201
# request_limit_checker #ACTIVE
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200
# #PROGRESSING: Iteration: 200.203
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.204
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.205
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.206
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.207
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 200.208
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.209
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.210
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.211
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.212
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.213
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.214
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.215
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.216
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.217
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.218
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.219
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.220
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.221
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.222
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.223
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 200.224
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.225
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.226
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.227
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.228
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.229
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.230
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.231
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.232
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.233
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.234
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.235
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.236
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.237
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.238
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.239
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# sleep 120s
# wake up
# #PROGRESSING: Iteration: 200.240
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.241
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.242
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.243
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.244
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.245
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.246
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.247
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.248
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.249
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.250
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.251
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.252
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.253
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.254
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.255
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 200.256
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.257
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.258
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.259
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.260
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.261
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.262
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.263
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.264
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.265
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.266
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.267
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.268
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.269
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.270
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.271
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 200.272
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.273
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.274
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.275
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.276
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.277
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.278
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.279
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.280
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.281
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.282
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.283
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.284
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.285
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.286
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.287
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 200.288
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.289
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.290
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.291
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.292
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.293
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.294
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.295
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.296
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.297
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.298
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.299
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.300
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.301
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 200.302
# request_limit_checker #ACTIVE
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 300
# #PROGRESSING: Iteration: 300.304
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.305
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.306
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.307
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.308
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.309
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.310
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.311
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.312
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.313
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.314
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.315
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.316
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.317
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.318
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.319
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# sleep 120s
# wake up
# #PROGRESSING: Iteration: 300.320
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.321
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.322
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.323
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.324
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.325
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.326
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.327
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.328
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.329
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.330
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.331
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.332
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.333
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.334
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.335
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 300.336
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.337
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.338
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.339
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.340
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.341
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.342
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.343
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.344
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.345
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.346
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.347
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.348
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.349
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.350
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.351
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 300.352
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.353
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.354
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.355
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.356
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.357
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.358
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.359
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.360
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.361
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.362
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.363
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.364
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.365
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.366
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.367
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 300.368
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.369
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.370
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.371
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.372
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.373
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.374
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.375
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.376
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.377
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.378
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.379
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.380
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.381
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.382
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.383
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 300.384
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.385
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.386
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.387
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.388
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.389
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.390
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.391
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.392
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.393
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.394
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.395
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.396
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.397
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.398
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.399
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# sleep 120s
# wake up
# #PROGRESSING: Iteration: 300.400
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.401
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.402
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 300.403
# request_limit_checker #ACTIVE
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400
# #PROGRESSING: Iteration: 400.405
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.406
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.407
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.408
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.409
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.410
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.411
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.412
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.413
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.414
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.415
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 400.416
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.417
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.418
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.419
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.420
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.421
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.422
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.423
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.424
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.425
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.426
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.427
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.428
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.429
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.430
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.431
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 400.432
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.433
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.434
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.435
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.436
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.437
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.438
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.439
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.440
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.441
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.442
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.443
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.444
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.445
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.446
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.447
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 400.448
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.449
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.450
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.451
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.452
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.453
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.454
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.455
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.456
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.457
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.458
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.459
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.460
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.461
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.462
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.463
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 400.464
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.465
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.466
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.467
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.468
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.469
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.470
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.471
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.472
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.473
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.474
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.475
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.476
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.477
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.478
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.479
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# sleep 120s
# wake up
# #PROGRESSING: Iteration: 400.480
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.481
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.482
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.483
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.484
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.485
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.486
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.487
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.488
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.489
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.490
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.491
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.492
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.493
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.494
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.495
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 400.496
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.497
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.498
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.499
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.500
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.501
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.502
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.503
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 400.504
# request_limit_checker #ACTIVE
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500
# #PROGRESSING: Iteration: 500.506
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.507
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.508
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.509
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.510
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.511
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 500.512
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.513
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.514
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.515
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.516
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.517
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.518
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.519
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.520
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.521
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.522
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.523
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.524
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.525
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.526
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.527
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 500.528
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.529
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.530
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.531
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.532
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.533
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.534
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.535
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.536
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.537
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.538
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.539
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.540
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.541
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.542
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.543
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 500.544
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.545
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.546
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.547
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.548
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.549
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.550
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.551
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.552
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.553
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.554
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.555
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.556
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.557
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.558
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.559
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# sleep 120s
# wake up
# #PROGRESSING: Iteration: 500.560
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.561
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.562
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.563
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.564
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.565
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.566
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.567
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.568
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.569
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.570
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.571
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.572
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.573
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.574
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.575
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 500.576
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.577
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.578
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.579
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.580
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.581
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.582
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.583
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.584
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.585
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.586
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.587
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.588
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.589
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.590
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.591
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 500.592
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.593
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.594
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.595
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.596
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.597
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.598
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.599
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.600
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.601
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.602
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.603
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.604
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 500.605
# request_limit_checker #ACTIVE
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600
# #PROGRESSING: Iteration: 600.607
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 600.608
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.609
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.610
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.611
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.612
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.613
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.614
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.615
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.616
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.617
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.618
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.619
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.620
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.621
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.622
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.623
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 600.624
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.625
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.626
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.627
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.628
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.629
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.630
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.631
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.632
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.633
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.634
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.635
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.636
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.637
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.638
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.639
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# sleep 120s
# wake up
# #PROGRESSING: Iteration: 600.640
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.641
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.642
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.643
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.644
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.645
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.646
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.647
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.648
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.649
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.650
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.651
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.652
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.653
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.654
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.655
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 600.656
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.657
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.658
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.659
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.660
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.661
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.662
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.663
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.664
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.665
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.666
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.667
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.668
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.669
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.670
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.671
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 600.672
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.673
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.674
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.675
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.676
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.677
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.678
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.679
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.680
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.681
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.682
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.683
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.684
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.685
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.686
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.687
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 600.688
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.689
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.690
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.691
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.692
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.693
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.694
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.695
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.696
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.697
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.698
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.699
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.700
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.701
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.702
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.703
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 600.704
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.705
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 600.706
# request_limit_checker #ACTIVE
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700
# #PROGRESSING: Iteration: 700.708
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.709
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.710
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.711
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.712
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.713
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.714
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.715
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.716
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.717
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.718
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.719
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# sleep 120s
# wake up
# #PROGRESSING: Iteration: 700.720
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.721
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.722
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.723
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.724
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.725
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.726
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.727
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.728
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.729
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.730
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.731
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.732
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.733
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.734
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.735
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 700.736
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.737
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.738
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.739
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.740
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.741
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.742
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.743
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.744
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.745
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.746
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.747
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.748
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.749
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.750
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.751
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 700.752
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.753
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.754
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.755
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.756
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.757
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.758
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.759
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.760
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.761
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.762
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.763
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.764
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.765
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.766
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.767
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 700.768
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.769
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.770
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.771
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.772
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.773
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.774
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.775
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.776
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.777
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.778
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.779
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.780
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.781
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.782
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.783
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 700.784
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.785
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.786
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.787
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.788
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.789
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.790
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.791
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.792
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.793
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.794
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.795
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.796
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.797
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.798
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.799
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# sleep 120s
# wake up
# #PROGRESSING: Iteration: 700.800
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.801
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.802
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.803
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.804
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.805
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.806
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 700.807
# request_limit_checker #ACTIVE
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800
# #PROGRESSING: Iteration: 800.809
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.810
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.811
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.812
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.813
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.814
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.815
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 800.816
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.817
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.818
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.819
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.820
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.821
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.822
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.823
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.824
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.825
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.826
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.827
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.828
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.829
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.830
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.831
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 800.832
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.833
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.834
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.835
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.836
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.837
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.838
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.839
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.840
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.841
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.842
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.843
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.844
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.845
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.846
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.847
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 800.848
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.849
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.850
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.851
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.852
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.853
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.854
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.855
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.856
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.857
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.858
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.859
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.860
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.861
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.862
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.863
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# #PROGRESSING: Iteration: 800.864
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.865
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.866
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.867
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.868
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.869
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.870
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.871
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.872
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.873
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.874
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.875
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.876
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.877
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.878
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.879
# request_limit_checker #ACTIVE
# sleep 1s
# wake up
# sleep 120s
# wake up
# #PROGRESSING: Iteration: 800.880
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.881
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.882
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.883
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.884
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 800.885
# request_limit_checker #ACTIVE
# request_limit_checker #ACTIVE
# #PROGRESSING: Iteration: 900
# #FINISH: No more games
# #FINISH: save_game_name_arr_to_json
